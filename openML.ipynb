# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#-----------------------------------------------------------------
from sklearn.datasets import fetch_openml
import pandas as pd

# https://www.openml.org/search?type=data&status=active&id=1120
#-------------------------------------------------------------------------
# Laden der Daten
data = fetch_openml(name='MagicTelescope', version=2) #version='active')

dfData = data.data
dfData['class'] = data.target
# Ersten Zeilen ausgeben
dfData.head()
# Out:
#    fLength:  fWidth:  fSize:  fConc:  fConc1:   fAsym:  fM3Long:  fM3Trans:  \
# 0   69.2979  26.8809  3.1930  0.2065   0.1074  39.6296   44.3457   -23.0604
# 1   24.5939  10.1418  2.5676  0.5007   0.2693  -8.4503   15.2452    -7.0283
# 2   55.4800  27.1606  3.1826  0.2299   0.1225  43.1016   54.2556    13.7406
# 3   12.6594  11.7413  2.1351  0.7033   0.3846 -15.8596    9.4522    -8.7126
# 4   38.6204  20.5632  2.9770  0.2478   0.1270 -13.8229  -31.3983   -13.1337
#
#    fAlpha:   fDist: class
# 0   9.3234  248.750     g
# 1  17.0056  173.288     g
# 2  32.2220  262.181     g
# 3  43.5434  227.711     g
# 4   5.8671  192.467     g

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#-----------------------------------------------------------------
from sklearn.datasets import fetch_openml
import pandas as pd

# https://www.openml.org/search?type=data&status=active&id=183
#-------------------------------------------------------------------------
# Laden der Daten
data = fetch_openml(name='abalone', version=1) #version='active')

dfData = data.data
dfData['Class_number_of_rings'] = data.target
# Ersten Zeilen ausgeben
dfData.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight Class_number_of_rings
# 0         0.150                    15
# 1         0.070                     7
# 2         0.210                     9
# 3         0.155                    10
# 4         0.055                     7

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#-----------------------------------------------------------------
from sklearn.datasets import fetch_openml
import pandas as pd

# https://www.openml.org/search?type=data&status=active&id=43531
#-------------------------------------------------------------------------
# Laden der Daten
data = fetch_openml(name='Gender-Classification-Dataset', version='active')

dfData = data.data
#dfData['Class'] = data.target
# Ersten Zeilen ausgeben
dfData.head(10)
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
# 5          1               13.0                 6.8          1          1
# 6          1               15.3                 6.2          1          1
# 7          0               13.0                 5.2          0          0
# 8          1               11.9                 5.4          1          0
# 9          1               12.1                 5.4          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender Class
# 0          1                          1    Male  None
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#-----------------------------------------------------------------
from sklearn.datasets import fetch_openml
import pandas as pd

# https://www.openml.org/search?type=data&status=active&id=43531
#-------------------------------------------------------------------------
# Laden der Daten
data = fetch_openml(name='fars', version=1) #version='active')

dfData = data.data
dfData['Class'] = data.target

print(dfData.shape)
# Ersten Zeilen ausgeben
dfData.head(10)
# Out:
# (100968, 30)
#    CASE_STATE  AGE SEX PERSON_TYPE  SEATING_POSITION  RESTRAINT_SYSTEM-USE  \
# 0           0   34   1           1                 3                     7
# 1           0   20   1           1                 3                     7
# 2           0   43   1           1                 3                     5
# 3           0   38   0           6                 6                     5
# 4           0   50   1           1                 3                     5
# 5           0   40   0           1                 3                     5
# 6           0   50   1           1                 3                     7
# 7           0   69   0           6                 6                     7
# 8           0   94   1           7                 8                     7
# 9           0   47   1           1                 3                     5
#
#    AIR_BAG_AVAILABILITY/DEPLOYMENT EJECTION EJECTION_PATH EXTRICATION  ...  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#-----------------------------------------------------------------
from sklearn.datasets import fetch_openml
import pandas as pd

# https://www.openml.org/search?type=data&status=active&id=43433
#-------------------------------------------------------------------------
# Laden der Daten
data = fetch_openml(name='Crystal-System-Properties-for-Li-ion-batteries', version='active')

dfData = data.data
dfData['Class'] = data.target

print(dfData.shape)
# Ersten Zeilen ausgeben
dfData.head(100)
# Out:
# (339, 12)
#    Materials_Id        Formula Spacegroup  Formation_Energy_(eV)  \
# 0     mp-849394      Li2MnSiO4         Pc                 -2.699
# 1     mp-783909      Li2MnSiO4      P21/c                 -2.696
# 2     mp-761311     Li4MnSi2O7         Cc                 -2.775
# 3     mp-761598   Li4Mn2Si3O10       C2/c                 -2.783
# 4     mp-767709   Li2Mn3Si3O10       C2/c                 -2.747
# ..          ...            ...        ...                    ...
# 95    mp-762714    Li2FeSi4O11       C2/c                 -2.785
# 96    mp-761452  Li2Fe(Si2O5)3         Cc                 -2.876
# 97    mp-780871   LiFe2(SiO4)2         P2                 -2.423
# 98    mp-763301      Li2CoSiO4         Pc                 -2.537
# 99    mp-764958      Li2CoSiO4        P21                 -2.523
#
#     E_Above_Hull_(eV)  Band_Gap_(eV)  Nsites  Density_(gm/cc)    Volume  \
# 0               0.006          3.462      16            2.993   178.513
# ...
